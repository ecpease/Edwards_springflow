# %%
import pandas as pd
import os
import numpy as np
import glob
import glob2
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter

# %matplotlib notebook

# %% [markdown]
# ## Delete all files that begin at 2018

# %%
workspace = os.path.join("..", "data", "precip", "NCDC", "output_stations")
dfs = []
stations = []
for file in glob.glob(os.path.join("..", "data", 'precip', 'NCDC', 'output_stations', "*.csv")):
    df=pd.read_csv(file)
    if df['DATE'][0].startswith("2018"):
        os.remove(file) 
#     dfs.append(df)
#     stations.append(file)
station_names = os.listdir(workspace)
for station in station_names:
    stations.append(station)
print(stations)
# Out:
# ['US1TXKR0054.csv', '.DS_Store', 'US1TXKR0079.csv', 'US1TXGS0018.csv', 'US1TXBND001.csv', 'US1TXBND029.csv', 'USC00415742.csv', '1966out.csv', 'US1TXBND022.csv', 'US1TXKR0074.csv', 'US1TXKR0065.csv', 'US1TXGS0039.csv', 'US1TXGS0038.csv']

# %%
df_test = pd.read_csv(os.path.join("..", "data", "precip", "NCDC", "output_stations", "US1TXGS0039.csv"))
df_test.set_index(pd.to_datetime(df_test['DATE']), inplace=True)
df_test.head()
# Out:
#             Unnamed: 0      STATION                 NAME  LATITUDE  LONGITUDE  \
# DATE
# 2012-10-25       18572  US1TXGS0039  HARPER 4.9 N, TX US   30.3711   -99.2528
# 2012-10-26       18573  US1TXGS0039  HARPER 4.9 N, TX US   30.3711   -99.2528
# 2012-10-27       18574  US1TXGS0039  HARPER 4.9 N, TX US   30.3711   -99.2528
# 2012-10-28       18575  US1TXGS0039  HARPER 4.9 N, TX US   30.3711   -99.2528
# 2012-10-29       18576  US1TXGS0039  HARPER 4.9 N, TX US   30.3711   -99.2528
#
#             ELEVATION        DATE  DAPR  MDPR  PRCP  TMAX  TMIN
# DATE
# 2012-10-25      659.6  2012-10-25   NaN   NaN  0.00   NaN   NaN
# 2012-10-26      659.6  2012-10-26   NaN   NaN  0.00   NaN   NaN
# 2012-10-27      659.6  2012-10-27   NaN   NaN  0.17   NaN   NaN
# 2012-10-28      659.6  2012-10-28   NaN   NaN  0.00   NaN   NaN
# 2012-10-29      659.6  2012-10-29   NaN   NaN  0.00   NaN   NaN

# %%
# if df['DATE'][0].startswith("2018"):

years = np.array(df_test['DATE'].unique)

# %%
years = YearLocator()  
yearsFmt = DateFormatter('%Y')

fig, ax = plt.subplots()
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(yearsFmt)
ax.autoscale_view()
# datemin = np.datetime64(df_test['DATE'][0], 'Y')
# datemax = np.datetime64(df_test['DATE'][-1], 'Y') + np.timedelta64(1, 'Y')
# ax.set_xlim(datemin, datemax)
df_test['DATE'] = pd.to_datetime(df_test['DATE'])
x = df_test['DATE']
y = df_test['PRCP']
# df_test.plot(kind='bar',x = 'DATE', y = 'PRCP',ax=ax)

# ax.barh(df_test['DATE'],df_test['PRCP'])

ax.bar(df_test.index, df_test['PRCP'], width=5, facecolor='indianred')


ax.set_xlabel("Date")
ax.set_ylabel("Precipitation (in)");
ax.set_title(f"Precip {station}")

# ax.bar(x, y)
ax.grid()
fig.autofmt_xdate()


# plt.show()
# plt.savefig(os.path.join("..", "img", ""))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()

df_66['DATE'] = pd.to_datetime(df_66['DATE'])

x = df_66['DATE']
y = df_66['PRCP']

ax.(x, y);

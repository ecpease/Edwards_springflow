# %%
import geopandas as gpd
import pandas as pd
import os

# %%
gdf1 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1530222.shp"))
gdf1
# Out:
#         STATION                          NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0   USC00415742            MEDINA 1 NE, TX US   29.8099   -99.2498      521.8
# 1   US1TXGS0038           HARPER 5.4 N, TX US   30.3783   -99.2497      642.8
# 2   US1TXGS0039           HARPER 4.9 N, TX US   30.3711   -99.2528      659.6
# 3   US1TXGS0018  FREDERICKSBURG 12.2 W, TX US   30.2617   -99.0766      617.8
# 4   US1TXBND029         BANDERA 4.7 NE, TX US   29.7714   -99.0161      448.4
# 5   US1TXBND001          MEDINA 3.0 NW, TX US   29.8323   -99.2781      463.6
# 6   US1TXKN0012         BOERNE 4.0 WSW, TX US   29.7626   -98.7868      483.1
# 7   US1TXBND022        BANDERA 8.6 NNW, TX US   29.8431   -99.1190      491.9
# 8   US1TXKN0010         BOERNE 6.0 WSW, TX US   29.7541   -98.8202      568.1
# 9   US1TXKR0079       KERRVILLE 6.3 SW, TX US   29.9706   -99.2011      556.3
# 10  US1TXKR0074      KERRVILLE 1.6 SSE, TX US   30.0202   -99.1290      491.0
# ...

# %%
gdf2 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1530223.shp"))
gdf2
# Out:
#         STATION                            NAME  LATITUDE  LONGITUDE  \
# 0   US1TXBXR215    HOLLYWOOD PARK 4.5 NE, TX US   29.6476   -98.4338
# 1   US1TXMSN006           MASON 17.3 ESE, TX US   30.6145   -98.9868
# 2   US1TXBXR075       SHAVANO PARK 1.1 W, TX US   29.5862   -98.5739
# 3   US1TXBXR192          HELOTES 2.4 NNW, TX US   29.5990   -98.7127
# 4   US1TXKN0089         SISTERDALE 5.7 N, TX US   30.0601   -98.7262
# 5   US1TXBXR218      CASTLE HILLS 0.7 NW, TX US   29.5301   -98.5275
# 6   US1TXBXR048   HOLLYWOOD PARK 1.7 ESE, TX US   29.5903   -98.4579
# 7   US1TXBXR146  FAIR OAKS RANCH 0.4 WSW, TX US   29.7348   -98.6425
# 8   US1TXBXR027       SCENIC OAKS 0.8 SW, TX US   29.7013   -98.6841
# 9   US1TXGS0024        WILLOW CITY 0.1 W, TX US   30.4007   -98.7022
# 10  US1TXBXR242   HOLLYWOOD PARK 3.7 NNE, TX US   29.6486   -98.4615
# 11  US1TXGS0025        WILLOW CITY 4.3 W, TX US   30.4103   -98.7730
# 12  US1TXGS0026   FREDERICKSBURG 11.4 NE, TX US   30.3833   -98.7321
# ...

# %%
gdf3 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1532043.shp"))
gdf3
# Out:
#         STATION                                      NAME  LATITUDE  \
# 0   USC00413686                        GRANGER DAM, TX US  30.71880
# 1   USC00415742                        MEDINA 1 NE, TX US  29.80990
# 2   USC00418415                         SMITHVILLE, TX US  30.00930
# 3   USC00413329                     FREDERICKSBURG, TX US  30.23910
# 4   USC00415429                             LULING, TX US  29.67550
# 5   USW00013958                  AUSTIN CAMP MABRY, TX US  30.32080
# 6   USC00413605                               GOLD, TX US  30.34810
# 7   USC00411429                         CANYON DAM, TX US  29.86070
# 8   USC00410738                      BERTRAM 3 ENE, TX US  30.76250
# 9   USC00418544                 SPRING BRANCH 2 SE, TX US  29.86520
# 10  USC00415272                              LLANO, TX US  30.74260
# 11  USC00414782                    KERRVILLE 3 NNE, TX US  30.07400
# 12  USC00416448                  NORTHINGTON RANCH, TX US  29.86480
# ...

# %%
gdf4 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1532076.shp"))
gdf4
# Out:
#         STATION                       NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0   USC00414402                 HYE, TX US  30.25330  -98.57110      443.8
# 1   USC00416448   NORTHINGTON RANCH, TX US  29.86480  -98.65820      434.3
# 2   USC00418877        TEAGUE RANCH, TX US  30.43320  -98.80970      524.3
# 3   USC00414605    JOHNSON CITY 2 N, TX US  30.30005  -98.40957      346.6
# 4   USC00410832              BLANCO, TX US  30.09500  -98.41420      399.3
# 5   USC00418544  SPRING BRANCH 2 SE, TX US  29.86520  -98.37960      306.3
# 6   USC00410902              BOERNE, TX US  29.79860  -98.73530      440.4
# 7   USC00413605                GOLD, TX US  30.34810  -98.68610      499.9
# 8   USC00418358     SISTERDALE 2 SE, TX US  29.95233  -98.71252      401.4
# 9   USC00417787      ROUND MOUNTAIN, TX US  30.42470  -98.34930      392.6
# 10  USC00413156      FISCHERS STORE, TX US  29.97450  -98.26700      359.7
#
#           DATE  PRCP                            geometry
# ...

# %%
gdf5 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1532080.shp"))
gdf5
# Out:
#         STATION                         NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0   USC00412585  DRIPPING SPRINGS 6 E, TX US  30.21950  -97.98790      330.4
# 1   USC00415429                LULING, TX US  29.67550  -97.65770      121.9
# 2   USW00013958     AUSTIN CAMP MABRY, TX US  30.32080  -97.76040      204.2
# 3   USC00419815        WIMBERLEY 1 NW, TX US  30.00160  -98.10480      275.8
# 4   USC00416276         NEW BRAUNFELS, TX US  29.65960  -98.16360      219.5
# 5   USC00417983            SAN MARCOS, TX US  29.88320  -97.94940      202.7
# 6   USC00415284              LOCKHART, TX US  29.88583  -97.69167      166.7
# 7   USC00411429            CANYON DAM, TX US  29.86070  -98.19590      304.8
# 8   USC00417791       ROUND ROCK 3 NE, TX US  30.54150  -97.63510      219.8
# 9   USC00413156        FISCHERS STORE, TX US  29.97450  -98.26700      359.7
# 10  USC00418531             SPICEWOOD, TX US  30.48128  -98.16066      259.1
#
# ...

# %%
gdf6 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1532085.shp"))
gdf6
# Out:
#        STATION                        NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00415822               MENARD, TX US  30.90445  -99.78658      603.2
# 1  USC00417480   RED BLUFF CROSSING, TX US  31.21750  -98.58330      376.4
# 2  USC00412630  DUNCAN WILSON RANCH, TX US  30.80000 -100.16667      646.2
# 3  USC00411017                BRADY, TX US  31.14453  -99.34922      521.5
# 4  USC00413614    GOLDTHWAITE 1 WSW, TX US  31.44050  -98.59020      459.3
# 5  USC00418863         TAYLOR RANCH, TX US  30.97303  -98.94323      556.3
# 6  USC00415272                LLANO, TX US  30.74260  -98.65430      310.9
# 7  USC00417593     RICHLAND SPRINGS, TX US  31.27000  -98.94861      420.6
# 8  USC00415650                MASON, TX US  30.74765  -99.23067      466.6
# 9  USC00417992             SAN SABA, TX US  31.18333  -98.71667      364.2
#
#          DATE  PRCP                             geometry
# 0  1930-01-01  0.00           POINT (-99.78658 30.90445)
# ...

# %%
gdf7 = gpd.read_file(os.path.join("..", "data", "precip", "NCDC", "shps", "1532091.shp"))
gdf7
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USC00415018            LAMPASAS, TX US  31.07170  -98.18470      314.6
# 1  USC00419099                 TOW, TX US  30.88370  -98.47070      312.7
# 2  USC00419504              WATSON, TX US  30.92970  -98.02200      310.3
# 3  USC00410738       BERTRAM 3 ENE, TX US  30.76250  -98.02130      344.1
# 4  USC00411250              BURNET, TX US  30.75870  -98.23390      391.7
# 5  USC00411580         CENTER CITY, TX US  31.46830  -98.41050      416.1
# 6  USC00416367       NIX STORE 1 W, TX US  31.10800  -98.37940      414.5
# 7  USC00411990  COPPERAS COVE 5 NW, TX US  31.16020  -97.95630      374.9
# 8  USC00418531           SPICEWOOD, TX US  30.48128  -98.16066      259.1
#
#          DATE  PRCP                             geometry
# 0  1930-01-01  0.00   POINT (-98.18470000000001 31.0717)
# 1  1978-04-01  0.00   POINT (-98.47069999999999 30.8837)
# ...

# %%
gdf = pd.concat([gdf1, gdf2, gdf3, gdf4, gdf5, gdf6, gdf7])
gdf
# Out:
#         STATION                            NAME  LATITUDE  LONGITUDE  \
# 0   USC00415742              MEDINA 1 NE, TX US  29.80990  -99.24980
# 1   US1TXGS0038             HARPER 5.4 N, TX US  30.37830  -99.24970
# 2   US1TXGS0039             HARPER 4.9 N, TX US  30.37110  -99.25280
# 3   US1TXGS0018    FREDERICKSBURG 12.2 W, TX US  30.26170  -99.07660
# 4   US1TXBND029           BANDERA 4.7 NE, TX US  29.77140  -99.01610
# 5   US1TXBND001            MEDINA 3.0 NW, TX US  29.83230  -99.27810
# 6   US1TXKN0012           BOERNE 4.0 WSW, TX US  29.76260  -98.78680
# 7   US1TXBND022          BANDERA 8.6 NNW, TX US  29.84310  -99.11900
# 8   US1TXKN0010           BOERNE 6.0 WSW, TX US  29.75410  -98.82020
# 9   US1TXKR0079         KERRVILLE 6.3 SW, TX US  29.97060  -99.20110
# 10  US1TXKR0074        KERRVILLE 1.6 SSE, TX US  30.02020  -99.12900
# 11  US1TXKR0054      CENTER POINT 0.5 SE, TX US  29.92940  -99.03050
# 12  US1TXKR0065            COMFORT 4.4 W, TX US  29.96180  -98.97550
# ...

# %%
gdf = gdf[~gdf['DATE'].astype(str).str.startswith('2018')]
# Out:
#         STATION                          NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0   USC00415742            MEDINA 1 NE, TX US  29.80990  -99.24980      521.8
# 1   US1TXGS0038           HARPER 5.4 N, TX US  30.37830  -99.24970      642.8
# 2   US1TXGS0039           HARPER 4.9 N, TX US  30.37110  -99.25280      659.6
# 3   US1TXGS0018  FREDERICKSBURG 12.2 W, TX US  30.26170  -99.07660      617.8
# 4   US1TXBND029         BANDERA 4.7 NE, TX US  29.77140  -99.01610      448.4
# 5   US1TXBND001          MEDINA 3.0 NW, TX US  29.83230  -99.27810      463.6
# 6   US1TXKN0012         BOERNE 4.0 WSW, TX US  29.76260  -98.78680      483.1
# 7   US1TXBND022        BANDERA 8.6 NNW, TX US  29.84310  -99.11900      491.9
# 8   US1TXKN0010         BOERNE 6.0 WSW, TX US  29.75410  -98.82020      568.1
# 9   US1TXKR0079       KERRVILLE 6.3 SW, TX US  29.97060  -99.20110      556.3
# 10  US1TXKR0074      KERRVILLE 1.6 SSE, TX US  30.02020  -99.12900      491.0
# ...

# %%
gdf.to_file(os.path.join("..", "data", "precip", "NCDC", "shps", "precip_merged_20181111.shp"))
# Out:
# /Users/emilypease/anaconda3/lib/python3.7/site-packages/geopandas/io/file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
df = gdf[["STATION", "NAME", "LATITUDE", "LONGITUDE", "ELEVATION", "DATE"]]
df.to_csv(os.path.join("..", "data", "precip", "NCDC", "merged_precip_csv", "precip_merged_20181111.csv"))
